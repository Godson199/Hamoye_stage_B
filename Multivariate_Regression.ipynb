# %% [markdown]
# ### Izuogu Chibuzor Godson
# Email: godsonizuogu@gmail.com

# %% [markdown]
# ## Table of contents:
#
# 1. [Importing libraries](#Libraries)
# 2. [Loading dataset](#Data)
# 3. [Statistical summaries](#Statistics)
# 4. [Missing values and duplicates](#Missing)
# 5. [Outliers detection](#Outliers)
# 6. [Correlations - EDA](#Correlations)
# 7. [Feature engineering](#Engineering)
# 8. [Data Preprocessing](#Preprocess)
# 9. [Modelling / Model evaluation](#Modelling)
# 10. [Making predictions of the test set and saving the model](#Predictions)

# %% [markdown]
# ## Importing Librries

# %%
# Importing important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %matplotlib inline
plt.rcParams["figure.figsize"]=(20,7)
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading Data

# %%
# Loading the Dataset
energy_data = pd.read_csv("energydata_complete.csv")#.set_index("date")
energy_data.head()#.reset_index()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
#    RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0    92.0   7.000000   63.000000        5.3  13.275433  13.275433
# 1    92.0   6.666667   59.166667        5.2  18.606195  18.606195
# 2    92.0   6.333333   55.333333        5.1  28.642668  28.642668
# 3    92.0   6.000000   51.500000        5.0  45.410389  45.410389
# 4    92.0   5.666667   47.666667        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %%
energy_data.shape
# Out:
# (19735, 29)

# %%
#rename columns
column_names = {'Appliances':'Appliances', 'lights':'lights', 'T1':'Temp_in_Kitchen_Area', 'RH_1':'Humidity_in_Kitchen_Area',
                'T2':'Temp_in_Living_Room_Area', 'RH_2':'Humidity_in_Living_Room_Area', 'T3':'Temp_in_Laundry_Room_Area',
                'RH_3':'Humidity_in_Living_Room_Area', 'T4':'Temp_in_office_Room','RH_4':'Humidity_in_Office_Room', 'T5':'Temp_in_Bathroom', 
                'RH_5':'Humidity_in_Bathroom', 'T6':'Temp_outside_the_Building', 'RH_6':'Humidity_outside_the_Building', 'T7':'Temp_in_Ironing_Room', 
                'RH_7':'Humidity_in_Ironing_Room', 'T8':'Temp_in_Teenager_Room_2', 'RH_8':'Humidity_in_Teenager_Room_2', 'T9':'Temp_in_Parents_Room',
                'RH_9':'Humidity_in_Parents_Room', 'T_out':'Temp_Outside', 'Press_mm_hg':'Press_mm_hg', 'RH_out':'Humidity_Outside', 'Windspeed':'Windspeed', 
                'Visibility':'Visibility', 'Tdewpoint':'Temp_Dew_Point', 'rv1':'Random_Variable_1', 'rv2':'Random_Variable_2'}

energy_data_1 = energy_data.rename(columns=column_names)
energy_data_1.head()
# Out:
#                   date  Appliances  lights  Temp_in_Kitchen_Area  \
# 0  2016-01-11 17:00:00          60      30                 19.89
# 1  2016-01-11 17:10:00          60      30                 19.89
# 2  2016-01-11 17:20:00          50      30                 19.89
# 3  2016-01-11 17:30:00          50      40                 19.89
# 4  2016-01-11 17:40:00          60      40                 19.89
#
#    Humidity_in_Kitchen_Area  Temp_in_Living_Room_Area  \
# 0                 47.596667                      19.2
# 1                 46.693333                      19.2
# 2                 46.300000                      19.2
# 3                 46.066667                      19.2
# 4                 46.333333                      19.2
#
#    Humidity_in_Living_Room_Area  Temp_in_Laundry_Room_Area  \
# 0                     44.790000                      19.79
# 1                     44.722500                      19.79
# 2                     44.626667                      19.79
# 3                     44.590000                      19.79
# 4                     44.530000                      19.79
#
#    Humidity_in_Living_Room_Area  Temp_in_office_Room  ...  \
# 0                     44.730000            19.000000  ...
# 1                     44.790000            19.000000  ...
# 2                     44.933333            18.926667  ...
# 3                     45.000000            18.890000  ...
# 4                     45.000000            18.890000  ...
#
#    Temp_in_Parents_Room  Humidity_in_Parents_Room  Temp_Outside  Press_mm_hg  \
# 0             17.033333                     45.53      6.600000        733.5
# 1             17.066667                     45.56      6.483333        733.6
# 2             17.000000                     45.50      6.366667        733.7
# 3             17.000000                     45.40      6.250000        733.8
# 4             17.000000                     45.40      6.133333        733.9
#
#    Humidity_Outside  Windspeed  Visibility  Temp_Dew_Point  Random_Variable_1  \
# 0              92.0   7.000000   63.000000             5.3          13.275433
# 1              92.0   6.666667   59.166667             5.2          18.606195
# 2              92.0   6.333333   55.333333             5.1          28.642668
# 3              92.0   6.000000   51.500000             5.0          45.410389
# 4              92.0   5.666667   47.666667             4.9          10.084097
#
#    Random_Variable_2
# 0          13.275433
# 1          18.606195
# 2          28.642668
# 3          45.410389
# 4          10.084097
#
# [5 rows x 29 columns]

# %%
# Prints out the names of the columns
energy_data_1.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'Temp_in_Kitchen_Area',
#        'Humidity_in_Kitchen_Area', 'Temp_in_Living_Room_Area',
#        'Humidity_in_Living_Room_Area', 'Temp_in_Laundry_Room_Area',
#        'Humidity_in_Living_Room_Area', 'Temp_in_office_Room',
#        'Humidity_in_Office_Room', 'Temp_in_Bathroom', 'Humidity_in_Bathroom',
#        'Temp_outside_the_Building', 'Humidity_outside_the_Building',
#        'Temp_in_Ironing_Room', 'Humidity_in_Ironing_Room',
#        'Temp_in_Teenager_Room_2', 'Humidity_in_Teenager_Room_2',
#        'Temp_in_Parents_Room', 'Humidity_in_Parents_Room', 'Temp_Outside',
#        'Press_mm_hg', 'Humidity_Outside', 'Windspeed', 'Visibility',
#        'Temp_Dew_Point', 'Random_Variable_1', 'Random_Variable_2'],
#       dtype='object')

# %%
len(energy_data_1.columns)
# Out:
# 29

# %%
# Checking the values in the two columns
energy_data_1[["Random_Variable_1", "Random_Variable_2"]]
# Out:
#        Random_Variable_1  Random_Variable_2
# 0              13.275433          13.275433
# 1              18.606195          18.606195
# 2              28.642668          28.642668
# 3              45.410389          45.410389
# 4              10.084097          10.084097
# ...                  ...                ...
# 19730          43.096812          43.096812
# 19731          49.282940          49.282940
# 19732          29.199117          29.199117
# 19733           6.322784           6.322784
# 19734          34.118851          34.118851
#
# [19735 rows x 2 columns]

# %% [markdown]
# ## Summary Statistics

# %%
energy_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   date                           19735 non-null  object
#  1   Appliances                     19735 non-null  int64
#  2   lights                         19735 non-null  int64
#  3   Temp_in_Kitchen_Area           19735 non-null  float64
#  4   Humidity_in_Kitchen_Area       19735 non-null  float64
#  5   Temp_in_Living_Room_Area       19735 non-null  float64
#  6   Humidity_in_Living_Room_Area   19735 non-null  float64
#  7   Temp_in_Laundry_Room_Area      19735 non-null  float64
#  8   Humidity_in_Living_Room_Area   19735 non-null  float64
#  9   Temp_in_office_Room            19735 non-null  float64
#  10  Humidity_in_Office_Room        19735 non-null  float64
#  11  Temp_in_Bathroom               19735 non-null  float64
#  12  Humidity_in_Bathroom           19735 non-null  float64
#  13  Temp_outside_the_Building      19735 non-null  float64
#  14  Humidity_outside_the_Building  19735 non-null  float64
#  15  Temp_in_Ironing_Room           19735 non-null  float64
#  16  Humidity_in_Ironing_Room       19735 non-null  float64
#  17  Temp_in_Teenager_Room_2        19735 non-null  float64
#  18  Humidity_in_Teenager_Room_2    19735 non-null  float64
#  19  Temp_in_Parents_Room           19735 non-null  float64
#  20  Humidity_in_Parents_Room       19735 non-null  float64
#  21  Temp_Outside                   19735 non-null  float64
#  22  Press_mm_hg                    19735 non-null  float64
#  23  Humidity_Outside               19735 non-null  float64
#  24  Windspeed                      19735 non-null  float64
#  25  Visibility                     19735 non-null  float64
#  26  Temp_Dew_Point                 19735 non-null  float64
#  27  Random_Variable_1              19735 non-null  float64
#  28  Random_Variable_2              19735 non-null  float64
# dtypes: float64(26), int64(2), object(1)
# memory usage: 4.4+ MB

# %% [markdown]
# ## Statistical Summaries

# %%
energy_data_1.describe()
# Out:
#          Appliances        lights  Temp_in_Kitchen_Area  \
# count  19735.000000  19735.000000          19735.000000
# mean      97.694958      3.801875             21.686571
# std      102.524891      7.935988              1.606066
# min       10.000000      0.000000             16.790000
# 25%       50.000000      0.000000             20.760000
# 50%       60.000000      0.000000             21.600000
# 75%      100.000000      0.000000             22.600000
# max     1080.000000     70.000000             26.260000
#
#        Humidity_in_Kitchen_Area  Temp_in_Living_Room_Area  \
# count              19735.000000              19735.000000
# mean                  40.259739                 20.341219
# std                    3.979299                  2.192974
# min                   27.023333                 16.100000
# 25%                   37.333333                 18.790000
# 50%                   39.656667                 20.000000
# 75%                   43.066667                 21.500000
# max                   63.360000                 29.856667
#
#        Humidity_in_Living_Room_Area  Temp_in_Laundry_Room_Area  \
# count                  19735.000000               19735.000000
# mean                      40.420420                  22.267611
# std                        4.069813                   2.006111
# min                       20.463333                  17.200000
# 25%                       37.900000                  20.790000
# 50%                       40.500000                  22.100000
# 75%                       43.260000                  23.290000
# max                       56.026667                  29.236000
#
#        Humidity_in_Living_Room_Area  Temp_in_office_Room  \
# count                  19735.000000         19735.000000
# mean                      39.242500            20.855335
# std                        3.254576             2.042884
# min                       28.766667            15.100000
# 25%                       36.900000            19.530000
# 50%                       38.530000            20.666667
# 75%                       41.760000            22.100000
# max                       50.163333            26.200000
#
#        Humidity_in_Office_Room  ...  Temp_in_Parents_Room  \
# count             19735.000000  ...          19735.000000
# mean                 39.026904  ...             19.485828
# std                   4.341321  ...              2.014712
# min                  27.660000  ...             14.890000
# 25%                  35.530000  ...             18.000000
# 50%                  38.400000  ...             19.390000
# 75%                  42.156667  ...             20.600000
# max                  51.090000  ...             24.500000
#
#        Humidity_in_Parents_Room  Temp_Outside   Press_mm_hg  Humidity_Outside  \
# count              19735.000000  19735.000000  19735.000000      19735.000000
# mean                  41.552401      7.411665    755.522602         79.750418
# std                    4.151497      5.317409      7.399441         14.901088
# min                   29.166667     -5.000000    729.300000         24.000000
# 25%                   38.500000      3.666667    750.933333         70.333333
# 50%                   40.900000      6.916667    756.100000         83.666667
# 75%                   44.338095     10.408333    760.933333         91.666667
# max                   53.326667     26.100000    772.300000        100.000000
#
#           Windspeed    Visibility  Temp_Dew_Point  Random_Variable_1  \
# count  19735.000000  19735.000000    19735.000000       19735.000000
# mean       4.039752     38.330834        3.760707          24.988033
# std        2.451221     11.794719        4.194648          14.496634
# min        0.000000      1.000000       -6.600000           0.005322
# 25%        2.000000     29.000000        0.900000          12.497889
# 50%        3.666667     40.000000        3.433333          24.897653
# 75%        5.500000     40.000000        6.566667          37.583769
# max       14.000000     66.000000       15.500000          49.996530
#
#        Random_Variable_2
# count       19735.000000
# mean           24.988033
# std            14.496634
# min             0.005322
# 25%            12.497889
# 50%            24.897653
# 75%            37.583769
# max            49.996530
#
# [8 rows x 28 columns]

# %% [markdown]
# ## Missing Values and Duplicates

# %%
# Check for missing values
energy_data_1.isnull().any().sum()
# Out:
# 0

# %% [markdown]
# No missing value

# %%
# Check for duplicates
energy_data_1.duplicated().any()
# Out:
# False

# %% [markdown]
# No duplicate values

# %% [markdown]
# ## Outlier Detection

# %%
 #Plotting boxplots for each of the numerical columns
sns.set_style('darkgrid')
fig, axes = plt.subplots(nrows = 3, ncols = 3, figsize = (20, 10))
fig.suptitle('Box plots showing outliers', y= 0.93, fontsize = 15)

for ax, data, name in zip(axes.flatten(), energy_data_1, ["Appliances",	"lights", "Temp_in_Kitchen_Area", "Humidity_in_Kitchen_Area", 
                                                          "Temp_in_Living_Room_Area", "Temp_in_Parents_Room", 
                                                          "Temp_in_Laundry_Room_Area", "Humidity_in_Parents_Room", 
                                                          "Temp_in_office_Room"]):
  sns.boxplot(energy_data_1[name], ax = ax)

# %% [markdown]
# ## Correlation - EDA

# %%
energy_data_1.corr()
# Out:
#                                Appliances    lights  Temp_in_Kitchen_Area  \
# Appliances                       1.000000  0.197278              0.055447
# lights                           0.197278  1.000000             -0.023528
# Temp_in_Kitchen_Area             0.055447 -0.023528              1.000000
# Humidity_in_Kitchen_Area         0.086031  0.106968              0.164006
# Temp_in_Living_Room_Area         0.120073 -0.005622              0.836834
# Humidity_in_Living_Room_Area    -0.060465  0.050985             -0.002509
# Temp_in_Laundry_Room_Area        0.085060 -0.097393              0.892402
# Humidity_in_Living_Room_Area     0.036292  0.131161             -0.028550
# Temp_in_office_Room              0.040281 -0.008859              0.877001
# Humidity_in_Office_Room          0.016965  0.114936              0.097861
# Temp_in_Bathroom                 0.019760 -0.078745              0.885247
# Humidity_in_Bathroom             0.006955  0.141233             -0.014782
# Temp_outside_the_Building        0.117638 -0.079029              0.654769
# Humidity_outside_the_Building   -0.083178  0.153756             -0.615045
# Temp_in_Ironing_Room             0.025801 -0.135347              0.838705
# Humidity_in_Ironing_Room        -0.055642  0.035069              0.135182
# Temp_in_Teenager_Room_2          0.039572 -0.071458              0.825413
# Humidity_in_Teenager_Room_2     -0.094039  0.012915             -0.006441
# Temp_in_Parents_Room             0.010010 -0.157592              0.844777
# Humidity_in_Parents_Room        -0.051462 -0.008766              0.071756
# Temp_Outside                     0.099155 -0.074424              0.682846
# Press_mm_hg                     -0.034885 -0.010576             -0.150574
# Humidity_Outside                -0.152282  0.068543             -0.345481
# Windspeed                        0.087122  0.060281             -0.087654
# Visibility                       0.000230  0.020038             -0.076210
# Temp_Dew_Point                   0.015353 -0.036322              0.571309
# Random_Variable_1               -0.011145  0.000521             -0.006203
# Random_Variable_2               -0.011145  0.000521             -0.006203
#
#                                Humidity_in_Kitchen_Area  \
# Appliances                                     0.086031
# lights                                         0.106968
# Temp_in_Kitchen_Area                           0.164006
# Humidity_in_Kitchen_Area                       1.000000
# Temp_in_Living_Room_Area                       0.269839
# Humidity_in_Living_Room_Area                   0.797535
# Temp_in_Laundry_Room_Area                      0.253230
# Humidity_in_Living_Room_Area                   0.844677
# Temp_in_office_Room                            0.106180
# Humidity_in_Office_Room                        0.880359
# Temp_in_Bathroom                               0.205797
# Humidity_in_Bathroom                           0.303258
# Temp_outside_the_Building                      0.316141
# Humidity_outside_the_Building                  0.245126
# Temp_in_Ironing_Room                           0.021397
# Humidity_in_Ironing_Room                       0.801122
# Temp_in_Teenager_Room_2                       -0.030053
# Humidity_in_Teenager_Room_2                    0.736196
# Temp_in_Parents_Room                           0.115263
# Humidity_in_Parents_Room                       0.764001
# Temp_Outside                                   0.340767
# Press_mm_hg                                   -0.293957
# Humidity_Outside                               0.274126
# Windspeed                                      0.204932
# Visibility                                    -0.021057
# Temp_Dew_Point                                 0.639106
# Random_Variable_1                             -0.000699
# Random_Variable_2                             -0.000699
#
#                                Temp_in_Living_Room_Area  \
# Appliances                                     0.120073
# lights                                        -0.005622
# Temp_in_Kitchen_Area                           0.836834
# Humidity_in_Kitchen_Area                       0.269839
# Temp_in_Living_Room_Area                       1.000000
# Humidity_in_Living_Room_Area                  -0.165610
# Temp_in_Laundry_Room_Area                      0.735245
# Humidity_in_Living_Room_Area                   0.121497
# Temp_in_office_Room                            0.762066
# Humidity_in_Office_Room                        0.231563
# Temp_in_Bathroom                               0.720550
# Humidity_in_Bathroom                           0.029595
# Temp_outside_the_Building                      0.801186
# Humidity_outside_the_Building                 -0.580372
# Temp_in_Ironing_Room                           0.663660
# Humidity_in_Ironing_Room                       0.229212
# Temp_in_Teenager_Room_2                        0.578191
# Humidity_in_Teenager_Room_2                    0.068534
# Temp_in_Parents_Room                           0.675535
# Humidity_in_Parents_Room                       0.157346
# Temp_Outside                                   0.792255
# Press_mm_hg                                   -0.133028
# Humidity_Outside                              -0.505291
# Windspeed                                      0.052495
# Visibility                                    -0.069721
# Temp_Dew_Point                                 0.582602
# Random_Variable_1                             -0.011087
# Random_Variable_2                             -0.011087
#
#                                Humidity_in_Living_Room_Area  \
# Appliances                                        -0.060465
# lights                                             0.050985
# Temp_in_Kitchen_Area                              -0.002509
# Humidity_in_Kitchen_Area                           0.797535
# Temp_in_Living_Room_Area                          -0.165610
# Humidity_in_Living_Room_Area                       1.000000
# Temp_in_Laundry_Room_Area                          0.137319
# Humidity_in_Living_Room_Area                       0.678326
# Temp_in_office_Room                               -0.047304
# Humidity_in_Office_Room                            0.721435
# Temp_in_Bathroom                                   0.110409
# Humidity_in_Bathroom                               0.250271
# Temp_outside_the_Building                         -0.009670
# Humidity_outside_the_Building                      0.389933
# Temp_in_Ironing_Room                              -0.051422
# Humidity_in_Ironing_Room                           0.690584
# Temp_in_Teenager_Room_2                           -0.041023
# Humidity_in_Teenager_Room_2                        0.679777
# Temp_in_Parents_Room                               0.054544
# Humidity_in_Parents_Room                           0.676467
# Temp_Outside                                       0.033674
# Press_mm_hg                                       -0.255646
# Humidity_Outside                                   0.584911
# Windspeed                                          0.069190
# Visibility                                        -0.005368
# Temp_Dew_Point                                     0.499152
# Random_Variable_1                                  0.006275
# Random_Variable_2                                  0.006275
#
#                                Temp_in_Laundry_Room_Area  \
# Appliances                                      0.085060
# lights                                         -0.097393
# Temp_in_Kitchen_Area                            0.892402
# Humidity_in_Kitchen_Area                        0.253230
# Temp_in_Living_Room_Area                        0.735245
# Humidity_in_Living_Room_Area                    0.137319
# Temp_in_Laundry_Room_Area                       1.000000
# Humidity_in_Living_Room_Area                   -0.011234
# Temp_in_office_Room                             0.852778
# Humidity_in_Office_Room                         0.122737
# Temp_in_Bathroom                                0.888169
# Humidity_in_Bathroom                           -0.066355
# Temp_outside_the_Building                       0.686882
# Humidity_outside_the_Building                  -0.647672
# Temp_in_Ironing_Room                            0.847374
# Humidity_in_Ironing_Room                        0.172624
# Temp_in_Teenager_Room_2                         0.795283
# Humidity_in_Teenager_Room_2                     0.044427
# Temp_in_Parents_Room                            0.901324
# Humidity_in_Parents_Room                        0.134602
# Temp_Outside                                    0.699417
# Press_mm_hg                                    -0.189974
# Humidity_Outside                               -0.281718
# Windspeed                                      -0.100776
# Visibility                                     -0.102310
# Temp_Dew_Point                                  0.645886
# Random_Variable_1                              -0.005194
# Random_Variable_2                              -0.005194
#
#                                Humidity_in_Living_Room_Area  \
# Appliances                                         0.036292
# lights                                             0.131161
# Temp_in_Kitchen_Area                              -0.028550
# Humidity_in_Kitchen_Area                           0.844677
# Temp_in_Living_Room_Area                           0.121497
# Humidity_in_Living_Room_Area                       0.678326
# Temp_in_Laundry_Room_Area                         -0.011234
# Humidity_in_Living_Room_Area                       1.000000
# Temp_in_office_Room                               -0.140457
# Humidity_in_Office_Room                            0.898978
# Temp_in_Bathroom                                  -0.050062
# Humidity_in_Bathroom                               0.375422
# Temp_outside_the_Building                          0.076833
# Humidity_outside_the_Building                      0.514912
# Temp_in_Ironing_Room                              -0.250090
# Humidity_in_Ironing_Room                           0.832685
# Temp_in_Teenager_Room_2                           -0.283228
# Humidity_in_Teenager_Room_2                        0.828822
# Temp_in_Parents_Room                              -0.195270
# Humidity_in_Parents_Room                           0.833538
# Temp_Outside                                       0.118207
# Press_mm_hg                                       -0.233274
# Humidity_Outside                                   0.356192
# Windspeed                                          0.263188
# Visibility                                         0.017041
# Temp_Dew_Point                                     0.414387
# Random_Variable_1                                 -0.000477
# Random_Variable_2                                 -0.000477
#
#                                Temp_in_office_Room  Humidity_in_Office_Room  \
# Appliances                                0.040281                 0.016965
# lights                                   -0.008859                 0.114936
# Temp_in_Kitchen_Area                      0.877001                 0.097861
# Humidity_in_Kitchen_Area                  0.106180                 0.880359
# Temp_in_Living_Room_Area                  0.762066                 0.231563
# Humidity_in_Living_Room_Area             -0.047304                 0.721435
# Temp_in_Laundry_Room_Area                 0.852778                 0.122737
# Humidity_in_Living_Room_Area             -0.140457                 0.898978
# Temp_in_office_Room                       1.000000                -0.048650
# Humidity_in_Office_Room                  -0.048650                 1.000000
# Temp_in_Bathroom                          0.871813                 0.091812
# Humidity_in_Bathroom                     -0.076489                 0.352591
# Temp_outside_the_Building                 0.652350                 0.259047
# Humidity_outside_the_Building            -0.703149                 0.392178
# Temp_in_Ironing_Room                      0.877763                -0.131204
# Humidity_in_Ironing_Room                  0.043527                 0.894301
# Temp_in_Teenager_Room_2                   0.796256                -0.167066
# Humidity_in_Teenager_Room_2              -0.095192                 0.847259
# Temp_in_Parents_Room                      0.889439                -0.044518
# Humidity_in_Parents_Room                 -0.025549                 0.856591
# Temp_Outside                              0.663478                 0.293289
# Press_mm_hg                              -0.075292                -0.250748
# Humidity_Outside                         -0.388602                 0.336813
# Windspeed                                -0.185747                 0.300192
# Visibility                               -0.104768                 0.002636
# Temp_Dew_Point                            0.519471                 0.616509
# Random_Variable_1                        -0.001815                -0.001787
# Random_Variable_2                        -0.001815                -0.001787
#
#                                ...  Temp_in_Parents_Room  \
# Appliances                     ...              0.010010
# lights                         ...             -0.157592
# Temp_in_Kitchen_Area           ...              0.844777
# Humidity_in_Kitchen_Area       ...              0.115263
# Temp_in_Living_Room_Area       ...              0.675535
# Humidity_in_Living_Room_Area   ...              0.054544
# Temp_in_Laundry_Room_Area      ...              0.901324
# Humidity_in_Living_Room_Area   ...             -0.195270
# Temp_in_office_Room            ...              0.889439
# Humidity_in_Office_Room        ...             -0.044518
# Temp_in_Bathroom               ...              0.911055
# Humidity_in_Bathroom           ...             -0.138509
# Temp_outside_the_Building      ...              0.667177
# Humidity_outside_the_Building  ...             -0.738940
# Temp_in_Ironing_Room           ...              0.944776
# Humidity_in_Ironing_Room       ...              0.028055
# Temp_in_Teenager_Room_2        ...              0.869338
# Humidity_in_Teenager_Room_2    ...             -0.113014
# Temp_in_Parents_Room           ...              1.000000
# Humidity_in_Parents_Room       ...             -0.008683
# Temp_Outside                   ...              0.668220
# Press_mm_hg                    ...             -0.156828
# Humidity_Outside               ...             -0.318848
# Windspeed                      ...             -0.177756
# Visibility                     ...             -0.103915
# Temp_Dew_Point                 ...              0.581483
# Random_Variable_1              ...             -0.001227
# Random_Variable_2              ...             -0.001227
#
#                                Humidity_in_Parents_Room  Temp_Outside  \
# Appliances                                    -0.051462      0.099155
# lights                                        -0.008766     -0.074424
# Temp_in_Kitchen_Area                           0.071756      0.682846
# Humidity_in_Kitchen_Area                       0.764001      0.340767
# Temp_in_Living_Room_Area                       0.157346      0.792255
# Humidity_in_Living_Room_Area                   0.676467      0.033674
# Temp_in_Laundry_Room_Area                      0.134602      0.699417
# Humidity_in_Living_Room_Area                   0.833538      0.118207
# Temp_in_office_Room                           -0.025549      0.663478
# Humidity_in_Office_Room                        0.856591      0.293289
# Temp_in_Bathroom                               0.072308      0.651321
# Humidity_in_Bathroom                           0.272197     -0.053126
# Temp_outside_the_Building                      0.184424      0.974787
# Humidity_outside_the_Building                  0.391943     -0.641572
# Temp_in_Ironing_Room                          -0.077690      0.631293
# Humidity_in_Ironing_Room                       0.858686      0.294199
# Temp_in_Teenager_Room_2                       -0.156820      0.502842
# Humidity_in_Teenager_Room_2                    0.855812      0.117141
# Temp_in_Parents_Room                          -0.008683      0.668220
# Humidity_in_Parents_Room                       1.000000      0.223270
# Temp_Outside                                   0.223270      1.000000
# Press_mm_hg                                   -0.183739     -0.143249
# Humidity_Outside                               0.359377     -0.574197
# Windspeed                                      0.238655      0.192936
# Visibility                                     0.008667     -0.077367
# Temp_Dew_Point                                 0.540328      0.790661
# Random_Variable_1                             -0.002955     -0.015216
# Random_Variable_2                             -0.002955     -0.015216
#
#                                Press_mm_hg  Humidity_Outside  Windspeed  \
# Appliances                       -0.034885         -0.152282   0.087122
# lights                           -0.010576          0.068543   0.060281
# Temp_in_Kitchen_Area             -0.150574         -0.345481  -0.087654
# Humidity_in_Kitchen_Area         -0.293957          0.274126   0.204932
# Temp_in_Living_Room_Area         -0.133028         -0.505291   0.052495
# Humidity_in_Living_Room_Area     -0.255646          0.584911   0.069190
# Temp_in_Laundry_Room_Area        -0.189974         -0.281718  -0.100776
# Humidity_in_Living_Room_Area     -0.233274          0.356192   0.263188
# Temp_in_office_Room              -0.075292         -0.388602  -0.185747
# Humidity_in_Office_Room          -0.250748          0.336813   0.300192
# Temp_in_Bathroom                 -0.170999         -0.273953  -0.145011
# Humidity_in_Bathroom             -0.119327          0.185941   0.082044
# Temp_outside_the_Building        -0.141643         -0.569119   0.169185
# Humidity_outside_the_Building    -0.065814          0.718587   0.098317
# Temp_in_Ironing_Room             -0.097724         -0.411213  -0.185892
# Humidity_in_Ironing_Room         -0.265850          0.378519   0.212979
# Temp_in_Teenager_Room_2          -0.162855         -0.300438  -0.218876
# Humidity_in_Teenager_Room_2      -0.225591          0.487355   0.202380
# Temp_in_Parents_Room             -0.156828         -0.318848  -0.177756
# Humidity_in_Parents_Room         -0.183739          0.359377   0.238655
# Temp_Outside                     -0.143249         -0.574197   0.192936
# Press_mm_hg                       1.000000         -0.092017  -0.235032
# Humidity_Outside                 -0.092017          1.000000  -0.176458
# Windspeed                        -0.235032         -0.176458   1.000000
# Visibility                        0.040315          0.083125  -0.007516
# Temp_Dew_Point                   -0.244098          0.036506   0.125972
# Random_Variable_1                 0.000699          0.020441  -0.011342
# Random_Variable_2                 0.000699          0.020441  -0.011342
#
#                                Visibility  Temp_Dew_Point  Random_Variable_1  \
# Appliances                       0.000230        0.015353          -0.011145
# lights                           0.020038       -0.036322           0.000521
# Temp_in_Kitchen_Area            -0.076210        0.571309          -0.006203
# Humidity_in_Kitchen_Area        -0.021057        0.639106          -0.000699
# Temp_in_Living_Room_Area        -0.069721        0.582602          -0.011087
# Humidity_in_Living_Room_Area    -0.005368        0.499152           0.006275
# Temp_in_Laundry_Room_Area       -0.102310        0.645886          -0.005194
# Humidity_in_Living_Room_Area     0.017041        0.414387          -0.000477
# Temp_in_office_Room             -0.104768        0.519471          -0.001815
# Humidity_in_Office_Room          0.002636        0.616509          -0.001787
# Temp_in_Bathroom                -0.084164        0.588362          -0.005490
# Humidity_in_Bathroom            -0.013133        0.078175          -0.011056
# Temp_outside_the_Building       -0.081313        0.764242          -0.015086
# Humidity_outside_the_Building    0.108705       -0.260417           0.011671
# Temp_in_Ironing_Room            -0.110089        0.466625          -0.003900
# Humidity_in_Ironing_Room        -0.007184        0.641857           0.001820
# Temp_in_Teenager_Room_2         -0.060098        0.391810          -0.003210
# Humidity_in_Teenager_Room_2      0.046178        0.501775           0.004480
# Temp_in_Parents_Room            -0.103915        0.581483          -0.001227
# Humidity_in_Parents_Room         0.008667        0.540328          -0.002955
# Temp_Outside                    -0.077367        0.790661          -0.015216
# Press_mm_hg                      0.040315       -0.244098           0.000699
# Humidity_Outside                 0.083125        0.036506           0.020441
# Windspeed                       -0.007516        0.125972          -0.011342
# Visibility                       1.000000       -0.042190          -0.005889
# Temp_Dew_Point                  -0.042190        1.000000          -0.003943
# Random_Variable_1               -0.005889       -0.003943           1.000000
# Random_Variable_2               -0.005889       -0.003943           1.000000
#
#                                Random_Variable_2
# Appliances                             -0.011145
# lights                                  0.000521
# Temp_in_Kitchen_Area                   -0.006203
# Humidity_in_Kitchen_Area               -0.000699
# Temp_in_Living_Room_Area               -0.011087
# Humidity_in_Living_Room_Area            0.006275
# Temp_in_Laundry_Room_Area              -0.005194
# Humidity_in_Living_Room_Area           -0.000477
# Temp_in_office_Room                    -0.001815
# Humidity_in_Office_Room                -0.001787
# Temp_in_Bathroom                       -0.005490
# Humidity_in_Bathroom                   -0.011056
# Temp_outside_the_Building              -0.015086
# Humidity_outside_the_Building           0.011671
# Temp_in_Ironing_Room                   -0.003900
# Humidity_in_Ironing_Room                0.001820
# Temp_in_Teenager_Room_2                -0.003210
# Humidity_in_Teenager_Room_2             0.004480
# Temp_in_Parents_Room                   -0.001227
# Humidity_in_Parents_Room               -0.002955
# Temp_Outside                           -0.015216
# Press_mm_hg                             0.000699
# Humidity_Outside                        0.020441
# Windspeed                              -0.011342
# Visibility                             -0.005889
# Temp_Dew_Point                         -0.003943
# Random_Variable_1                       1.000000
# Random_Variable_2                       1.000000
#
# [28 rows x 28 columns]

# %% [markdown]
# ## Data Visualization

# %%
# Plotting a heatmap to check the correlation
plt.figure(figsize=(20,8))
sns.heatmap(energy_data_1.corr(), cmap='RdYlGn', annot=True, center=0)
plt.savefig('corr.png', bbox_inches='tight')

# %%
# Taking some sample of the dataset to plot a regression plot in other to check the correlation of some features
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)
simple_linear_reg_df = energy_data_1[["Temp_Outside", "Appliances"]].sample(30, random_state=2)
#regression plot
sns.regplot(x= "Temp_Outside", y= "Appliances", data=simple_linear_reg_df, ax=ax1)

simple_linear_reg_df = energy_data_1[["Appliances", "Temp_in_Living_Room_Area"]].sample(30, random_state=2)
#regression plot
sns.regplot(x= "Temp_in_Living_Room_Area", y="Appliances", data=simple_linear_reg_df, ax=ax2)

simple_linear_reg_df = energy_data_1[["Appliances", "Temp_in_Laundry_Room_Area"]].sample(30, random_state=2)
#regression plot
sns.regplot(x="Temp_in_Laundry_Room_Area", y= "Appliances", data=simple_linear_reg_df, ax=ax3)

simple_linear_reg_df = energy_data_1[["Appliances", "Temp_outside_the_Building"]].sample(30, random_state=2)
#regression plot
sns.regplot(x= "Temp_outside_the_Building", y= "Appliances", data=simple_linear_reg_df, ax=ax4)
# Out:
# <AxesSubplot:xlabel='Temp_outside_the_Building', ylabel='Appliances'>

# %% [markdown]
# Correlation exists between the above features

# %% [markdown]
# ## Feature Engineering

# %%
energy_data_1['date'] = pd.to_datetime(energy_data_1['date']).dt.normalize()

# %%
energy_data_1['date'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
# Extract day, month year and hour from the Datetime column
# day
energy_data_1['Datetime_day'] = energy_data_1.date.dt.day

# month
energy_data_1['Datetime_month'] = energy_data_1.date.dt.month
 
# year
energy_data_1['Datetime_year'] = energy_data_1.date.dt.year

# hour
energy_data_1['Datetime_hour'] = energy_data_1.date.dt.hour

# Preview engineered date features
energy_data_1[['date', 'Datetime_day', 'Datetime_month', 'Datetime_year', 'Datetime_hour']].head()
# Out:
#         date  Datetime_day  Datetime_month  Datetime_year  Datetime_hour
# 0 2016-01-11            11               1           2016              0
# 1 2016-01-11            11               1           2016              0
# 2 2016-01-11            11               1           2016              0
# 3 2016-01-11            11               1           2016              0
# 4 2016-01-11            11               1           2016              0

# %%
energy_data_1["Datetime_month"].unique()
# Out:
# array([1, 2, 3, 4, 5], dtype=int64)

# %%
# Datetime month countplot
plt.figure(figsize = (14, 7))
sns.countplot(x = 'Datetime_month', data = energy_data_1)
plt.title('Datetime month count plot')
plt.show()

# %% [markdown]
# - The only months available in the train set include *Jan, Feb, March, April and May*
# - January has the least number of observations in the dataset while March has the highest number of observations

# %% [markdown]
# ## Data Preprocessing

# %%
energy_data_1.head(3)
# Out:
#         date  Appliances  lights  Temp_in_Kitchen_Area  \
# 0 2016-01-11          60      30                 19.89
# 1 2016-01-11          60      30                 19.89
# 2 2016-01-11          50      30                 19.89
#
#    Humidity_in_Kitchen_Area  Temp_in_Living_Room_Area  \
# 0                 47.596667                      19.2
# 1                 46.693333                      19.2
# 2                 46.300000                      19.2
#
#    Humidity_in_Living_Room_Area  Temp_in_Laundry_Room_Area  \
# 0                     44.790000                      19.79
# 1                     44.722500                      19.79
# 2                     44.626667                      19.79
#
#    Humidity_in_Living_Room_Area  Temp_in_office_Room  ...  Humidity_Outside  \
# 0                     44.730000            19.000000  ...              92.0
# 1                     44.790000            19.000000  ...              92.0
# 2                     44.933333            18.926667  ...              92.0
#
#    Windspeed  Visibility  Temp_Dew_Point  Random_Variable_1  \
# 0   7.000000   63.000000             5.3          13.275433
# 1   6.666667   59.166667             5.2          18.606195
# 2   6.333333   55.333333             5.1          28.642668
#
#    Random_Variable_2  Datetime_day  Datetime_month  Datetime_year  \
# 0          13.275433            11               1           2016
# 1          18.606195            11               1           2016
# 2          28.642668            11               1           2016
#
#    Datetime_hour
# 0              0
# 1              0
# 2              0
#
# [3 rows x 33 columns]

# %% [markdown]
# ## Modelling

# %%
# Question 13
# removing the date and lights column
energy_data_2 = energy_data_1.drop(["date", "lights", "Random_Variable_2", "Random_Variable_1"],axis=1)


# Normalizing and scaling the dataset using MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalised_df = pd.DataFrame(scaler.fit_transform(energy_data_2), columns=energy_data_2.columns)
features_df = normalised_df.drop(columns=energy_data_2[["Appliances"]])
target = normalised_df["Appliances"]

# %%
#Splitting the dataset for model training
from sklearn.model_selection import train_test_split
X = features_df
y = target
random_state = 42

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=random_state)


#Training the model
from sklearn.linear_model import LinearRegression
linear_model_1 = LinearRegression(n_jobs=5)
linear_model_1.fit(x_train, y_train)

#making Predictions
predicted_values_1 = linear_model_1.predict(x_test)

# model evalution on the test set
print('Your Accuracy is: ', linear_model_1.score(x_test, y_test) )
# Out:
# Your Accuracy is:  0.15000199355105104

# %%
# Checking the Mean Absolute Error in 2 d.p
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predicted_values_1)
print("The mean absolute error:", round(mae, 2 ))
# Out:
# The mean absolute error: 0.05

# %%
# The residual sum of squares
rss = np.sum(np.square(y_test - predicted_values_1))
print("The residual sum of squares is:", round(rss, 2))
# Out:
# The residual sum of squares is: 45.31

# %%
# The root mean squared error in 3 d.p
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted_values_1))
print("The root mean squared error is:", round(rmse, 3))
# Out:
# The root mean squared error is: 0.087

# %%
# Coefficient of Determination
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_values_1)
print("The coefficient of determination is:", round(r2_score, 2))
# Out:
# The coefficient of determination is: 0.15

# %%
# Question 17
# Obtaining the weights of the features#comparing the effects of regularisation
def get_weights_df(model, feat, col_name):
#this function returns the weight of every feature
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    return weights_df


linear_model_weights = get_weights_df(linear_model_1, x_train, 'Linear_Model_Weight')
linear_model_weights
# Out:
#                          Features  Linear_Model_Weight
# 0    Humidity_in_Living_Room_Area            -0.450517
# 1        Temp_in_Living_Room_Area            -0.241934
# 2                    Temp_Outside            -0.239659
# 3     Humidity_in_Teenager_Room_2            -0.147266
# 4            Temp_in_Parents_Room            -0.142074
# 5                  Datetime_month            -0.063330
# 6        Humidity_in_Parents_Room            -0.055221
# 7        Humidity_in_Ironing_Room            -0.042860
# 8                Humidity_Outside            -0.027933
# 9            Temp_in_Kitchen_Area            -0.017778
# 10               Temp_in_Bathroom            -0.011903
# 11                   Datetime_day            -0.011279
# 12           Temp_in_Ironing_Room            -0.000310
# 13                  Datetime_year             0.000000
# 14                  Datetime_hour             0.000000
# 15              Random_Variable_1             0.001596
# 16  Humidity_outside_the_Building             0.008599
# 17                    Press_mm_hg             0.008840
# 18                     Visibility             0.011418
# 19           Humidity_in_Bathroom             0.014187
# 20        Humidity_in_Office_Room             0.014638
# 21                      Windspeed             0.024029
# 22            Temp_in_office_Room             0.028878
# 23   Humidity_in_Living_Room_Area             0.075751
# 24                 Temp_Dew_Point             0.093847
# 25        Temp_in_Teenager_Room_2             0.102284
# 26      Temp_outside_the_Building             0.218132
# 27      Temp_in_Laundry_Room_Area             0.314468
# 28       Humidity_in_Kitchen_Area             0.551324

# %%
# Question 18
# Training a ridge regression model with an alpha value of 0.4
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(x_train, y_train)

# making preedictions
ridge_predict = ridge_reg.predict(x_test)


rmse = np.sqrt(mean_squared_error(y_test, ridge_predict))
print("The ridge root mean squared error is:", round(rmse, 3))
print("There's a difference in the RMSE")
# Out:
# The ridge root mean squared error is: 0.087
# There's a difference in the RMSE

# %%
# Question 19
# Training a lasso regression with an alpha of 0.001
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(x_train, y_train)

#making predictions
lasso_predict = lasso_reg.predict(x_test)
print(lasso_predict)
# Obtaining the new feature weights
 
def get_weights_df(model, feat, col_name):
#this function returns the weight of every feature
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    return weights_df


lasso_weights_df = get_weights_df(lasso_reg, x_train, 'Lasso_weight')
lasso_weights_df
# Out:
# [0.07332955 0.08551566 0.07692773 ... 0.07672252 0.08841482 0.0810908 ]
#                          Features  Lasso_weight
# 0                Humidity_Outside     -0.050882
# 1                  Datetime_month     -0.006761
# 2     Humidity_in_Teenager_Room_2     -0.003461
# 3            Temp_in_Kitchen_Area      0.000000
# 4                    Datetime_day     -0.000000
# 5               Random_Variable_1     -0.000000
# 6                  Temp_Dew_Point      0.000000
# 7                      Visibility      0.000000
# 8                       Windspeed      0.000000
# 9                     Press_mm_hg     -0.000000
# 10                   Temp_Outside      0.000000
# 11       Humidity_in_Parents_Room     -0.000000
# 12           Temp_in_Parents_Room     -0.000000
# 13                  Datetime_year      0.000000
# 14        Temp_in_Teenager_Room_2      0.000000
# 15           Temp_in_Ironing_Room     -0.000000
# 16  Humidity_outside_the_Building     -0.000000
# 17      Temp_outside_the_Building      0.000000
# 18           Humidity_in_Bathroom      0.000000
# 19               Temp_in_Bathroom     -0.000000
# 20        Humidity_in_Office_Room      0.000000
# 21            Temp_in_office_Room      0.000000
# 22   Humidity_in_Living_Room_Area      0.000000
# 23      Temp_in_Laundry_Room_Area      0.000000
# 24   Humidity_in_Living_Room_Area     -0.000000
# 25       Humidity_in_Ironing_Room     -0.000000
# 26                  Datetime_hour      0.000000
# 27       Temp_in_Living_Room_Area      0.004511
# 28       Humidity_in_Kitchen_Area      0.019894

# %%
# New RMSE with the lasso regression
rmse = np.sqrt(mean_squared_error(y_test, lasso_predict))
print("The new root mean squared error with lasso regression is:", round(rmse, 3))
# Out:
# The new root mean squared error with lasso regression is: 0.093

# %% [markdown]
# #### Hyperparameter Tuning

# %%
#Try other models to figure out which one gives the best score using GridSearchCV
from sklearn.model_selection import ShuffleSplit, cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
#from catboost import CatBoostRegressor

#We now write a function

def find_best_model_using_gridsearchcv(X,y):
    algos = {
        "linear_regression":{
            "model":LinearRegression(),
            "params":{
                "normalize":[True, False]
            }
        },
        
        "ridge": {
            "model": Ridge(),
            "params": {
                "alpha": [1,2],
                "normalize":[True, False]
            }
        },
                
        "lasso": {
            "model": Lasso(),
            "params": {
                "alpha": [1,2],
                "selection": ["random", "cyclic"]
            }
        },
        
        "decision_tree": {
            "model": DecisionTreeRegressor(),
            "params": {
                "criterion": ["mse", "friedman_mse"],
                "splitter": ["best", "random"]
            }
        }
    }
    
    #To save the model into a dataframe
    
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs = GridSearchCV(config["model"], config["params"], cv=cv, return_train_score=False)
        gs.fit(X,y)
        scores.append({
            "model":algo_name,
            "best_score":gs.best_score_,
            "best_params":gs.best_params_
        })
        
    return pd.DataFrame(scores, columns=["model","best_score", "best_params"])

# Calling the function

find_best_model_using_gridsearchcv(X,y)
# Out:
#                model  best_score                                 best_params
# 0  linear_regression    0.145374                         {'normalize': True}
# 1              ridge    0.144737            {'alpha': 1, 'normalize': False}
# 2              lasso   -0.000659         {'alpha': 1, 'selection': 'random'}
# 3      decision_tree    0.265401  {'criterion': 'mse', 'splitter': 'random'}

# %%
# Using Cross Validtion to get the best model
#creating a shufflesplit will randomize the sample and give a better accuracy
from sklearn.model_selection import ShuffleSplit, cross_val_score
cv = ShuffleSplit(n_splits=5, test_size=0.3, random_state=42)

cross_val_score(LinearRegression(), X,y, cv=cv)
# Out:
# array([0.15000199, 0.14984111, 0.13501898, 0.14707182, 0.14602196])

# %%
# Saving the best model
import pickle
with open("energy_mode", "wb") as f:
    pickle.dump(linear_model, f)
